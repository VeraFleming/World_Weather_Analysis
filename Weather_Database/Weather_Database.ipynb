# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
# If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(15)

        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")


# Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
     
         
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
     # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})   

        
      
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | plast
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | saint-pierre
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | kamenka
# Processing Record 9 of Set 1 | gronau
# Processing Record 10 of Set 1 | camacha
# Processing Record 11 of Set 1 | caxito
# Processing Record 12 of Set 1 | luena
# Processing Record 13 of Set 1 | carballo
# Processing Record 14 of Set 1 | chabahar
# Processing Record 15 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 1 | monastyrshchina
# Processing Record 17 of Set 1 | kilindoni
# Processing Record 18 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 1 | camana
# Processing Record 20 of Set 1 | bouar
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | chapais
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | beni
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | verkhnyaya inta
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | bonthe
# Processing Record 33 of Set 1 | kalabo
# Processing Record 34 of Set 1 | tabuk
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | kisanga
# Processing Record 37 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 1 | skerries
# Processing Record 39 of Set 1 | mahanoro
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | pescara
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | najran
# Processing Record 46 of Set 1 | atyrau
# Processing Record 47 of Set 1 | soyo
# Processing Record 48 of Set 1 | narsaq
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | xacmaz
# Processing Record 2 of Set 2 | polunochnoye
# Processing Record 3 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | riyadh
# Processing Record 6 of Set 2 | gonen
# Processing Record 7 of Set 2 | caluquembe
# Processing Record 8 of Set 2 | olinda
# Processing Record 9 of Set 2 | tshikapa
# Processing Record 10 of Set 2 | sept-iles
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | medvedok
# Processing Record 14 of Set 2 | salekhard
# Processing Record 15 of Set 2 | roald
# Processing Record 16 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 17 of Set 2 | guapore
# Processing Record 18 of Set 2 | iralaya
# Processing Record 19 of Set 2 | inirida
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | cockburn town
# Processing Record 22 of Set 2 | buraydah
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | oksfjord
# Processing Record 26 of Set 2 | bossembele
# City not found. Skipping...
# Processing Record 27 of Set 2 | malumfashi
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | pangnirtung
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | san carlos de bariloche
# Processing Record 32 of Set 2 | korla
# Processing Record 33 of Set 2 | kutum
# Processing Record 34 of Set 2 | mount pleasant
# Processing Record 35 of Set 2 | marawi
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | omboue
# Processing Record 38 of Set 2 | hooksett
# Processing Record 39 of Set 2 | sinnamary
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | manavalakurichi
# Processing Record 43 of Set 2 | male
# Processing Record 44 of Set 2 | laguna
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | mopti
# Processing Record 47 of Set 2 | viedma
# Processing Record 48 of Set 2 | mykolayivka
# Processing Record 49 of Set 2 | sinazongwe
# Processing Record 50 of Set 2 | salalah
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | san cristobal
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | aksarka
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | swidnik
# Processing Record 7 of Set 3 | guaruja
# Processing Record 8 of Set 3 | gogrial
# Processing Record 9 of Set 3 | abalak
# Processing Record 10 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 3 | saldanha
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 3 | lincoln
# Processing Record 15 of Set 3 | yelovo
# Processing Record 16 of Set 3 | eirunepe
# Processing Record 17 of Set 3 | buenos aires
# Processing Record 18 of Set 3 | cabedelo
# Processing Record 19 of Set 3 | puerto madryn
# Processing Record 20 of Set 3 | aswan
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | adrar
# Processing Record 23 of Set 3 | berlevag
# Processing Record 24 of Set 3 | promissao
# Processing Record 25 of Set 3 | phalombe
# Processing Record 26 of Set 3 | vangaindrano
# Processing Record 27 of Set 3 | zambezi
# Processing Record 28 of Set 3 | nsukka
# Processing Record 29 of Set 3 | hambantota
# Processing Record 30 of Set 3 | abu samrah
# Processing Record 31 of Set 3 | ziniare
# Processing Record 32 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 3 | alta floresta
# Processing Record 34 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | maragogi
# Processing Record 37 of Set 3 | liverpool
# Processing Record 38 of Set 3 | caravelas
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | aleksandrovka
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | boca do acre
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | kipini
# Processing Record 45 of Set 3 | puerto colombia
# Processing Record 46 of Set 3 | port-gentil
# Processing Record 47 of Set 3 | leh
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | saint-leu
# Processing Record 50 of Set 3 | yar-sale
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | hendersonville
# Processing Record 4 of Set 4 | harnai
# Processing Record 5 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 4 | pimentel
# Processing Record 7 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 4 | riberalta
# Processing Record 9 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | chaman
# Processing Record 12 of Set 4 | ugoofaaru
# Processing Record 13 of Set 4 | lahuachaca
# Processing Record 14 of Set 4 | willowmore
# Processing Record 15 of Set 4 | arlit
# Processing Record 16 of Set 4 | quatre cocos
# Processing Record 17 of Set 4 | bereda
# Processing Record 18 of Set 4 | piacabucu
# Processing Record 19 of Set 4 | peniche
# Processing Record 20 of Set 4 | santa cruz cabralia
# Processing Record 21 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 4 | am timan
# Processing Record 23 of Set 4 | mutoko
# Processing Record 24 of Set 4 | pryazha
# Processing Record 25 of Set 4 | lagoa
# Processing Record 26 of Set 4 | agara
# Processing Record 27 of Set 4 | tombouctou
# Processing Record 28 of Set 4 | saint anthony
# Processing Record 29 of Set 4 | nouadhibou
# Processing Record 30 of Set 4 | saint-joseph
# Processing Record 31 of Set 4 | gravdal
# Processing Record 32 of Set 4 | penalva
# Processing Record 33 of Set 4 | lilongwe
# Processing Record 34 of Set 4 | abiramam
# Processing Record 35 of Set 4 | marquette
# Processing Record 36 of Set 4 | arkhipo-osipovka
# Processing Record 37 of Set 4 | helmstedt
# Processing Record 38 of Set 4 | songea
# Processing Record 39 of Set 4 | la palma
# Processing Record 40 of Set 4 | sur
# Processing Record 41 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 4 | kaabong
# Processing Record 44 of Set 4 | bonavista
# Processing Record 45 of Set 4 | manturovo
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | chapada dos guimaraes
# Processing Record 48 of Set 4 | coihaique
# Processing Record 49 of Set 4 | usinsk
# Processing Record 50 of Set 4 | mitu
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | sokoni
# Processing Record 3 of Set 5 | breves
# Processing Record 4 of Set 5 | santa cruz del norte
# Processing Record 5 of Set 5 | manzil kamil
# Processing Record 6 of Set 5 | nuristan
# Processing Record 7 of Set 5 | turtas
# Processing Record 8 of Set 5 | lar gerd
# City not found. Skipping...
# Processing Record 9 of Set 5 | moissac
# Processing Record 10 of Set 5 | chambas
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | kushmurun
# Processing Record 13 of Set 5 | sistranda
# Processing Record 14 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 15 of Set 5 | manga
# Processing Record 16 of Set 5 | altay
# Processing Record 17 of Set 5 | kaduna
# Processing Record 18 of Set 5 | miranda de ebro
# Processing Record 19 of Set 5 | mutis
# Processing Record 20 of Set 5 | porto torres
# Processing Record 21 of Set 5 | mattru
# Processing Record 22 of Set 5 | ilebo
# Processing Record 23 of Set 5 | dalbandin
# Processing Record 24 of Set 5 | meulaboh
# Processing Record 25 of Set 5 | tefe
# Processing Record 26 of Set 5 | bibiani
# Processing Record 27 of Set 5 | coquimbo
# Processing Record 28 of Set 5 | andros town
# Processing Record 29 of Set 5 | ancud
# Processing Record 30 of Set 5 | state college
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | tiznit
# Processing Record 33 of Set 5 | anloga
# Processing Record 34 of Set 5 | mangan
# Processing Record 35 of Set 5 | khash
# Processing Record 36 of Set 5 | bikaner
# Processing Record 37 of Set 5 | tamandare
# Processing Record 38 of Set 5 | sorland
# Processing Record 39 of Set 5 | karachi
# Processing Record 40 of Set 5 | big bend
# Processing Record 41 of Set 5 | boqueirao
# Processing Record 42 of Set 5 | mogadishu
# Processing Record 43 of Set 5 | logansport
# Processing Record 44 of Set 5 | berwick
# Processing Record 45 of Set 5 | filingue
# Processing Record 46 of Set 5 | alghero
# Processing Record 47 of Set 5 | bahia blanca
# Processing Record 48 of Set 5 | la asuncion
# Processing Record 49 of Set 5 | aksu
# Processing Record 50 of Set 5 | kattivakkam
# Processing Record 1 of Set 6 | millerovo
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | axim
# Processing Record 4 of Set 6 | sabaudia
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | ostrovnoy
# Processing Record 7 of Set 6 | dudinka
# Processing Record 8 of Set 6 | sibiti
# Processing Record 9 of Set 6 | mirabad
# Processing Record 10 of Set 6 | pemba
# Processing Record 11 of Set 6 | muravlenko
# Processing Record 12 of Set 6 | cauquenes
# Processing Record 13 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 6 | longyearbyen
# Processing Record 15 of Set 6 | kerman
# Processing Record 16 of Set 6 | sitarganj
# Processing Record 17 of Set 6 | barnala
# Processing Record 18 of Set 6 | bamako
# Processing Record 19 of Set 6 | severnyy
# Processing Record 20 of Set 6 | talara
# Processing Record 21 of Set 6 | general roca
# Processing Record 22 of Set 6 | camocim
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | vicuna
# Processing Record 26 of Set 6 | praia da vitoria
# Processing Record 27 of Set 6 | rorvik
# Processing Record 28 of Set 6 | krasnyy yar
# Processing Record 29 of Set 6 | ashta
# Processing Record 30 of Set 6 | talcahuano
# Processing Record 31 of Set 6 | havre-saint-pierre
# Processing Record 32 of Set 6 | margate
# Processing Record 33 of Set 6 | mehamn
# Processing Record 34 of Set 6 | naryan-mar
# Processing Record 35 of Set 6 | luderitz
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | rio gallegos
# Processing Record 38 of Set 6 | itapirapua
# Processing Record 39 of Set 6 | henties bay
# Processing Record 40 of Set 6 | portobelo
# Processing Record 41 of Set 6 | chicama
# Processing Record 42 of Set 6 | bengkulu
# Processing Record 43 of Set 6 | vidalia
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | nanortalik
# Processing Record 46 of Set 6 | newport
# Processing Record 47 of Set 6 | moura
# Processing Record 48 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 6 | morondava
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | sault sainte marie
# Processing Record 2 of Set 7 | timra
# Processing Record 3 of Set 7 | hualmay
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 6 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 7 of Set 7 | bollnas
# Processing Record 8 of Set 7 | halifax
# Processing Record 9 of Set 7 | scarborough
# Processing Record 10 of Set 7 | el jicaro
# Processing Record 11 of Set 7 | kudahuvadhoo
# Processing Record 12 of Set 7 | amalapuram
# Processing Record 13 of Set 7 | diebougou
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | dosso
# Processing Record 16 of Set 7 | chia
# Processing Record 17 of Set 7 | fonte boa
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | shirak
# Processing Record 20 of Set 7 | suez
# Processing Record 21 of Set 7 | hofn
# Processing Record 22 of Set 7 | bilma
# Processing Record 23 of Set 7 | tocopilla
# Processing Record 24 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 7 | sokolo
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | comodoro rivadavia
# Processing Record 28 of Set 7 | saint-augustin
# Processing Record 29 of Set 7 | ponta delgada
# Processing Record 30 of Set 7 | sarkikaraagac
# Processing Record 31 of Set 7 | chhabra
# Processing Record 32 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 33 of Set 7 | ous
# Processing Record 34 of Set 7 | aguadulce
# Processing Record 35 of Set 7 | parasia
# Processing Record 36 of Set 7 | marystown
# Processing Record 37 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 7 | sisimiut
# Processing Record 39 of Set 7 | resistencia
# Processing Record 40 of Set 7 | ajdabiya
# Processing Record 41 of Set 7 | veraval
# Processing Record 42 of Set 7 | senneterre
# Processing Record 43 of Set 7 | mecca
# Processing Record 44 of Set 7 | burica
# City not found. Skipping...
# Processing Record 45 of Set 7 | kem
# Processing Record 46 of Set 7 | rabat
# Processing Record 47 of Set 7 | lima
# Processing Record 48 of Set 7 | waddan
# Processing Record 49 of Set 7 | bardiyah
# Processing Record 50 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 1 of Set 8 | mangaluru
# Processing Record 2 of Set 8 | san rafael
# Processing Record 3 of Set 8 | raudeberg
# Processing Record 4 of Set 8 | kolpashevo
# Processing Record 5 of Set 8 | bandarbeyla
# Processing Record 6 of Set 8 | el cobre
# Processing Record 7 of Set 8 | uribia
# Processing Record 8 of Set 8 | antalaha
# Processing Record 9 of Set 8 | tarko-sale
# Processing Record 10 of Set 8 | umm lajj
# Processing Record 11 of Set 8 | masuguru
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | praia
# Processing Record 14 of Set 8 | batouri
# Processing Record 15 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | orocue
# Processing Record 17 of Set 8 | marsh harbour
# Processing Record 18 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 8 | llano de piedra
# Processing Record 20 of Set 8 | artvin
# Processing Record 21 of Set 8 | akkudah
# City not found. Skipping...
# Processing Record 22 of Set 8 | monrovia
# Processing Record 23 of Set 8 | tremembe
# Processing Record 24 of Set 8 | shubarkuduk
# Processing Record 25 of Set 8 | morant bay
# Processing Record 26 of Set 8 | amapa
# Processing Record 27 of Set 8 | tougan
# Processing Record 28 of Set 8 | svencioneliai
# Processing Record 29 of Set 8 | yazd
# Processing Record 30 of Set 8 | kailahun
# Processing Record 31 of Set 8 | manta
# Processing Record 32 of Set 8 | yenagoa
# Processing Record 33 of Set 8 | klenovyy
# Processing Record 34 of Set 8 | villarrica
# Processing Record 35 of Set 8 | kalmar
# Processing Record 36 of Set 8 | unye
# City not found. Skipping...
# Processing Record 37 of Set 8 | takoradi
# Processing Record 38 of Set 8 | beloha
# Processing Record 39 of Set 8 | koroni
# Processing Record 40 of Set 8 | koprivnica
# Processing Record 41 of Set 8 | russkaya polyana
# Processing Record 42 of Set 8 | batatais
# Processing Record 43 of Set 8 | tome-acu
# City not found. Skipping...
# Processing Record 44 of Set 8 | high rock
# Processing Record 45 of Set 8 | vondrozo
# Processing Record 46 of Set 8 | tashtyp
# Processing Record 47 of Set 8 | cap malheureux
# Processing Record 48 of Set 8 | calama
# Processing Record 49 of Set 8 | shetpe
# Processing Record 50 of Set 8 | sao jose da coroa grande
# Processing Record 1 of Set 9 | kokstad
# Processing Record 2 of Set 9 | sambava
# Processing Record 3 of Set 9 | abha
# Processing Record 4 of Set 9 | biloli
# Processing Record 5 of Set 9 | harper
# Processing Record 6 of Set 9 | havoysund
# Processing Record 7 of Set 9 | gat
# Processing Record 8 of Set 9 | pauini
# Processing Record 9 of Set 9 | kapoeta
# Processing Record 10 of Set 9 | xuddur
# Processing Record 11 of Set 9 | den helder
# Processing Record 12 of Set 9 | leshukonskoye
# Processing Record 13 of Set 9 | filadelfia
# Processing Record 14 of Set 9 | pakhtakoron
# Processing Record 15 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 9 | saint albans
# Processing Record 17 of Set 9 | andreapol
# Processing Record 18 of Set 9 | huambo
# Processing Record 19 of Set 9 | kongolo
# Processing Record 20 of Set 9 | murgab
# Processing Record 21 of Set 9 | ikalamavony
# Processing Record 22 of Set 9 | kangaatsiaq
# Processing Record 23 of Set 9 | jeremie
# Processing Record 24 of Set 9 | rio grande
# Processing Record 25 of Set 9 | oktyabrsk
# Processing Record 26 of Set 9 | gao
# Processing Record 27 of Set 9 | jizan
# Processing Record 28 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 9 | nuuk
# Processing Record 30 of Set 9 | springbok
# Processing Record 31 of Set 9 | mookane
# Processing Record 32 of Set 9 | santa maria
# Processing Record 33 of Set 9 | pegnitz
# Processing Record 34 of Set 9 | tias
# Processing Record 35 of Set 9 | alpena
# Processing Record 36 of Set 9 | olafsvik
# Processing Record 37 of Set 9 | bayji
# Processing Record 38 of Set 9 | farafangana
# Processing Record 39 of Set 9 | addis zemen
# City not found. Skipping...
# Processing Record 40 of Set 9 | tsiroanomandidy
# Processing Record 41 of Set 9 | muros
# Processing Record 42 of Set 9 | vorsma
# Processing Record 43 of Set 9 | saquarema
# Processing Record 44 of Set 9 | kartuzy
# Processing Record 45 of Set 9 | opuwo
# Processing Record 46 of Set 9 | lapithos
# Processing Record 47 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 9 | salamiyah
# Processing Record 49 of Set 9 | huarmey
# Processing Record 50 of Set 9 | purranque
# Processing Record 1 of Set 10 | nioro
# Processing Record 2 of Set 10 | mbarara
# Processing Record 3 of Set 10 | sal rei
# Processing Record 4 of Set 10 | maceio
# Processing Record 5 of Set 10 | shymkent
# Processing Record 6 of Set 10 | ortigueira
# Processing Record 7 of Set 10 | senanga
# Processing Record 8 of Set 10 | yining
# Processing Record 9 of Set 10 | setermoen
# Processing Record 10 of Set 10 | savyntsi
# Processing Record 11 of Set 10 | blind river
# Processing Record 12 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 10 | vasai
# Processing Record 14 of Set 10 | harfleur
# Processing Record 15 of Set 10 | circleville
# Processing Record 16 of Set 10 | ariquemes
# Processing Record 17 of Set 10 | san martin
# Processing Record 18 of Set 10 | san juan
# Processing Record 19 of Set 10 | aripuana
# Processing Record 20 of Set 10 | samana
# Processing Record 21 of Set 10 | sadovoye
# Processing Record 22 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 10 | terra santa
# Processing Record 24 of Set 10 | torbat-e jam
# Processing Record 25 of Set 10 | marabba
# Processing Record 26 of Set 10 | mwene-ditu
# Processing Record 27 of Set 10 | gamba
# Processing Record 28 of Set 10 | pontarlier
# Processing Record 29 of Set 10 | abrego
# Processing Record 30 of Set 10 | fort oglethorpe
# Processing Record 31 of Set 10 | richards bay
# Processing Record 32 of Set 10 | hornepayne
# Processing Record 33 of Set 10 | bay roberts
# Processing Record 34 of Set 10 | quarai
# Processing Record 35 of Set 10 | faya
# Processing Record 36 of Set 10 | mukhtolovo
# Processing Record 37 of Set 10 | san borja
# Processing Record 38 of Set 10 | ritchie
# Processing Record 39 of Set 10 | derzhavinsk
# Processing Record 40 of Set 10 | raga
# Processing Record 41 of Set 10 | vila do maio
# Processing Record 42 of Set 10 | safita
# Processing Record 43 of Set 10 | kharp
# Processing Record 44 of Set 10 | el real de santa maria
# Processing Record 45 of Set 10 | samoded
# Processing Record 46 of Set 10 | machiques
# Processing Record 47 of Set 10 | colchester
# Processing Record 48 of Set 10 | iracoubo
# Processing Record 49 of Set 10 | dolores
# Processing Record 50 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 11 | buzuluk
# Processing Record 2 of Set 11 | umm kaddadah
# Processing Record 3 of Set 11 | le port
# Processing Record 4 of Set 11 | tema
# Processing Record 5 of Set 11 | zaraza
# Processing Record 6 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 11 | loralai
# Processing Record 8 of Set 11 | gazanjyk
# Processing Record 9 of Set 11 | reconquista
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | dori
# Processing Record 12 of Set 11 | nileshwar
# Processing Record 13 of Set 11 | zhob
# Processing Record 14 of Set 11 | mandvi
# Processing Record 15 of Set 11 | oistins
# Processing Record 16 of Set 11 | alma
# Processing Record 17 of Set 11 | siimusti
# Processing Record 18 of Set 11 | jardim
# Processing Record 19 of Set 11 | goderich
# Processing Record 20 of Set 11 | euclid
# Processing Record 21 of Set 11 | ziri
# Processing Record 22 of Set 11 | gryazovets
# Processing Record 23 of Set 11 | fredericksburg
# Processing Record 24 of Set 11 | velingrad
# Processing Record 25 of Set 11 | nurota
# Processing Record 26 of Set 11 | tukrah
# Processing Record 27 of Set 11 | constantine
# Processing Record 28 of Set 11 | brae
# Processing Record 29 of Set 11 | lewisporte
# Processing Record 30 of Set 11 | ponazyrevo
# Processing Record 31 of Set 11 | luanda
# Processing Record 32 of Set 11 | mongo
# Processing Record 33 of Set 11 | tabas
# Processing Record 34 of Set 11 | jacmel
# Processing Record 35 of Set 11 | nova praha
# Processing Record 36 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 11 | chanika
# Processing Record 38 of Set 11 | narva-joesuu
# Processing Record 39 of Set 11 | mangrol
# Processing Record 40 of Set 11 | kassala
# Processing Record 41 of Set 11 | jalu
# Processing Record 42 of Set 11 | coroata
# Processing Record 43 of Set 11 | malakal
# Processing Record 44 of Set 11 | conde
# Processing Record 45 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 46 of Set 11 | sutysky
# Processing Record 47 of Set 11 | emba
# Processing Record 48 of Set 11 | inhambane
# Processing Record 49 of Set 11 | mantua
# Processing Record 50 of Set 11 | escanaba
# Processing Record 1 of Set 12 | radishchevo
# Processing Record 2 of Set 12 | taltal
# Processing Record 3 of Set 12 | sharjah
# Processing Record 4 of Set 12 | elat
# Processing Record 5 of Set 12 | crixas
# Processing Record 6 of Set 12 | warrington
# Processing Record 7 of Set 12 | sao gabriel da cachoeira
# Processing Record 8 of Set 12 | iberia
# Processing Record 9 of Set 12 | aasiaat
# Processing Record 10 of Set 12 | juba
# Processing Record 11 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 12 | bambui
# Processing Record 13 of Set 12 | moose factory
# Processing Record 14 of Set 12 | plettenberg bay
# Processing Record 15 of Set 12 | okoneshnikovo
# Processing Record 16 of Set 12 | sao felix do xingu
# Processing Record 17 of Set 12 | rincon
# Processing Record 18 of Set 12 | belaya kholunitsa
# Processing Record 19 of Set 12 | gisenyi
# Processing Record 20 of Set 12 | komsomolskiy
# Processing Record 21 of Set 12 | tashtagol
# Processing Record 22 of Set 12 | moussoro
# Processing Record 23 of Set 12 | guajara
# Processing Record 24 of Set 12 | zaysan
# Processing Record 25 of Set 12 | sancti spiritus
# Processing Record 26 of Set 12 | nizhniy odes
# Processing Record 27 of Set 12 | abong mbang
# Processing Record 28 of Set 12 | iquique
# Processing Record 29 of Set 12 | maine-soroa
# Processing Record 30 of Set 12 | pisco
# Processing Record 31 of Set 12 | maniitsoq
# Processing Record 32 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 12 | kamenskiy
# Processing Record 34 of Set 12 | hvolsvollur
# Processing Record 35 of Set 12 | venado tuerto
# Processing Record 36 of Set 12 | begles
# Processing Record 37 of Set 12 | paita
# Processing Record 38 of Set 12 | presidente epitacio
# Processing Record 39 of Set 12 | bestobe
# Processing Record 40 of Set 12 | orangeburg
# Processing Record 41 of Set 12 | saint-denis
# Processing Record 42 of Set 12 | adamantina
# Processing Record 43 of Set 12 | oxford
# Processing Record 44 of Set 12 | vila franca do campo
# Processing Record 45 of Set 12 | la rinconada
# Processing Record 46 of Set 12 | albany
# Processing Record 47 of Set 12 | hobyo
# Processing Record 48 of Set 12 | marsaxlokk
# Processing Record 49 of Set 12 | atsipopoulon
# Processing Record 50 of Set 12 | andijon
# Processing Record 1 of Set 13 | baleshwar
# Processing Record 2 of Set 13 | coroico
# Processing Record 3 of Set 13 | floro
# Processing Record 4 of Set 13 | dvinskoy
# Processing Record 5 of Set 13 | puerto escondido
# Processing Record 6 of Set 13 | basoko
# Processing Record 7 of Set 13 | vitina
# Processing Record 8 of Set 13 | totskoye
# Processing Record 9 of Set 13 | marzuq
# Processing Record 10 of Set 13 | port shepstone
# Processing Record 11 of Set 13 | grindavik
# Processing Record 12 of Set 13 | kreuzau
# Processing Record 13 of Set 13 | ostersund
# Processing Record 14 of Set 13 | westport
# Processing Record 15 of Set 13 | marienburg
# Processing Record 16 of Set 13 | zelenoborskiy
# Processing Record 17 of Set 13 | grand gaube
# Processing Record 18 of Set 13 | saint-francois
# Processing Record 19 of Set 13 | nampula
# Processing Record 20 of Set 13 | bara
# Processing Record 21 of Set 13 | penzance
# Processing Record 22 of Set 13 | dhidhdhoo
# Processing Record 23 of Set 13 | borgo san dalmazzo
# Processing Record 24 of Set 13 | eyl
# Processing Record 25 of Set 13 | bokoro
# Processing Record 26 of Set 13 | santander
# Processing Record 27 of Set 13 | bowling green
# Processing Record 28 of Set 13 | zharkent
# Processing Record 29 of Set 13 | usvyaty
# Processing Record 30 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 13 | sabha
# Processing Record 32 of Set 13 | haukipudas
# Processing Record 33 of Set 13 | honningsvag
# Processing Record 34 of Set 13 | hubli
# Processing Record 35 of Set 13 | at-bashi
# Processing Record 36 of Set 13 | altea
# Processing Record 37 of Set 13 | guayabetal
# Processing Record 38 of Set 13 | tangara
# Processing Record 39 of Set 13 | gurupa
# Processing Record 40 of Set 13 | kraliky
# Processing Record 41 of Set 13 | chingirlau
# Processing Record 42 of Set 13 | vysotsk
# Processing Record 43 of Set 13 | malanje
# Processing Record 44 of Set 13 | tashla
# Processing Record 45 of Set 13 | oriximina
# Processing Record 46 of Set 13 | puerto ayacucho
# Processing Record 47 of Set 13 | mastic beach
# Processing Record 48 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 13 | el angel
# Processing Record 1 of Set 14 | kotido
# Processing Record 2 of Set 14 | husavik
# Processing Record 3 of Set 14 | ayagoz
# Processing Record 4 of Set 14 | sechura
# Processing Record 5 of Set 14 | carutapera
# Processing Record 6 of Set 14 | asyut
# Processing Record 7 of Set 14 | sinop
# Processing Record 8 of Set 14 | krasnoselkup
# Processing Record 9 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 14 | sesori
# Processing Record 11 of Set 14 | prata
# Processing Record 12 of Set 14 | salihorsk
# Processing Record 13 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 14 of Set 14 | kimberley
# Processing Record 15 of Set 14 | isparta
# Processing Record 16 of Set 14 | tire
# Processing Record 17 of Set 14 | sao bernardo do campo
# Processing Record 18 of Set 14 | agadir
# Processing Record 19 of Set 14 | vallenar
# Processing Record 20 of Set 14 | semey
# Processing Record 21 of Set 14 | sakakah
# Processing Record 22 of Set 14 | walvis bay
# Processing Record 23 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 24 of Set 14 | yarmouth
# Processing Record 25 of Set 14 | aguimes
# Processing Record 26 of Set 14 | birjand
# Processing Record 27 of Set 14 | jutai
# Processing Record 28 of Set 14 | khanpur
# Processing Record 29 of Set 14 | beroroha
# Processing Record 30 of Set 14 | daoukro
# Processing Record 31 of Set 14 | uyemskiy
# Processing Record 32 of Set 14 | plouzane
# Processing Record 33 of Set 14 | mitsamiouli
# Processing Record 34 of Set 14 | shache
# Processing Record 35 of Set 14 | pimampiro
# Processing Record 36 of Set 14 | santa luzia
# Processing Record 37 of Set 14 | nsanje
# Processing Record 38 of Set 14 | mage
# Processing Record 39 of Set 14 | privolzhskiy
# Processing Record 40 of Set 14 | guhagar
# Processing Record 41 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 14 | arnoldstein
# Processing Record 43 of Set 14 | woodhaven
# Processing Record 44 of Set 14 | cururupu
# Processing Record 45 of Set 14 | itaituba
# Processing Record 46 of Set 14 | nantucket
# Processing Record 47 of Set 14 | inta
# Processing Record 48 of Set 14 | hare bay
# Processing Record 49 of Set 14 | thurso
# Processing Record 50 of Set 14 | esil
# Processing Record 1 of Set 15 | freiberg
# Processing Record 2 of Set 15 | divnoye
# Processing Record 3 of Set 15 | ciudad bolivar
# Processing Record 4 of Set 15 | agirish
# Processing Record 5 of Set 15 | micheweni
# Processing Record 6 of Set 15 | the valley
# Processing Record 7 of Set 15 | antofagasta
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 15 | pervomayskoye
# Processing Record 11 of Set 15 | puerto berrio
# Processing Record 12 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 15 | camopi
# Processing Record 14 of Set 15 | kabompo
# Processing Record 15 of Set 15 | correntina
# Processing Record 16 of Set 15 | sesheke
# Processing Record 17 of Set 15 | bani
# Processing Record 18 of Set 15 | dunmore east
# Processing Record 19 of Set 15 | podporozhye
# Processing Record 20 of Set 15 | la rioja
# Processing Record 21 of Set 15 | staryy nadym
# Processing Record 22 of Set 15 | salinopolis
# Processing Record 23 of Set 15 | kuytun
# Processing Record 24 of Set 15 | dharchula
# Processing Record 25 of Set 15 | adre
# Processing Record 26 of Set 15 | kochubey
# Processing Record 27 of Set 15 | fort-shevchenko
# Processing Record 28 of Set 15 | tando muhammad khan
# Processing Record 29 of Set 15 | dutse
# Processing Record 30 of Set 15 | darnah
# Processing Record 31 of Set 15 | dhadar
# Processing Record 32 of Set 15 | abidjan
# Processing Record 33 of Set 15 | sindand
# City not found. Skipping...
# Processing Record 34 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 15 | sines
# Processing Record 36 of Set 15 | rezekne
# Processing Record 37 of Set 15 | presidencia roque saenz pena
# Processing Record 38 of Set 15 | felipe carrillo puerto
# Processing Record 39 of Set 15 | ozinki
# Processing Record 40 of Set 15 | saposoa
# Processing Record 41 of Set 15 | mayor pablo lagerenza
# Processing Record 42 of Set 15 | severnoye
# Processing Record 43 of Set 15 | amilly
# Processing Record 44 of Set 15 | tessalit
# Processing Record 45 of Set 15 | santa vitoria
# Processing Record 46 of Set 15 | kuraymah
# Processing Record 47 of Set 15 | brokopondo
# Processing Record 48 of Set 15 | mtimbira
# Processing Record 49 of Set 15 | ouadda
# Processing Record 50 of Set 15 | lubango
# Processing Record 1 of Set 16 | aktau
# Processing Record 2 of Set 16 | boende
# Processing Record 3 of Set 16 | benguela
# Processing Record 4 of Set 16 | novyy urengoy
# Processing Record 5 of Set 16 | karakol
# Processing Record 6 of Set 16 | emborion
# Processing Record 7 of Set 16 | diffa
# Processing Record 8 of Set 16 | kidal
# Processing Record 9 of Set 16 | kholmogory
# Processing Record 10 of Set 16 | prado
# Processing Record 11 of Set 16 | joura
# Processing Record 12 of Set 16 | icara
# Processing Record 13 of Set 16 | turukhansk
# Processing Record 14 of Set 16 | grand valley
# Processing Record 15 of Set 16 | tallahassee
# Processing Record 16 of Set 16 | havelock
# Processing Record 17 of Set 16 | uddevalla
# Processing Record 18 of Set 16 | magadi
# Processing Record 19 of Set 16 | matara
# Processing Record 20 of Set 16 | gouyave
# Processing Record 21 of Set 16 | dvorichna
# Processing Record 22 of Set 16 | kamennomostskoye
# Processing Record 23 of Set 16 | naerbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 # Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Plast      RU  54.3691  60.8136     52.47        89          13
# 1     Jamestown      US  42.0970 -79.2353     85.59        56           0
# 2     Upernavik      GL  72.7868 -56.1549     48.69        68          89
# 3  Saint-Pierre      RE -21.3393  55.4781     69.48        63          20
# 4       Ushuaia      AR -54.8000 -68.3000     31.66        74          75
# 5     Cape Town      ZA -33.9258  18.4232     57.38        77           0
# 6   Clyde River      CA  70.4692 -68.5914     37.83        90         100
# 7       Kamenka      RU  51.3223  42.7678     57.25        88          83
# 8        Gronau      DE  52.2000   7.0333     72.10        83          71
# 9       Camacha      PT  33.0833 -16.3333     67.42        78          75
#
#    Wind Speed Current Description
# 0        8.63          few clouds
# 1       11.50           clear sky
# 2        7.02     overcast clouds
# 3       23.02          few clouds
# 4       14.97       broken clouds
# 5        3.20           clear sky
# 6        2.06     overcast clouds
# 7        4.81       broken clouds
# 8        4.34       moderate rain
# 9       10.36       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
